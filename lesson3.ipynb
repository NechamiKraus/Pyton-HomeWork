# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.1-cp39-cp39-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.1-cp39-cp39-win_amd64.whl (11.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'שם': ['אליז', 'בת שבע', 'גליה'],
        'כיתה': [12, 8, 4],
        'ממוצע ציונים': [42, 98, 89]}

# %%
sample = pd.DataFrame(data)
sample
# Out:
#        שם  כיתה  ממוצע ציונים
# 0    אליז    12            42
# 1  בת שבע     8            98
# 2    גליה     4            89

# %%
new_row = {'שם': 'נעמי', 'כיתה': 5, 'ממוצע ציונים': 99}

# %%
sample.loc[len(sample)] = new_row

# %%
type(sample.iloc[1])
# Out:
# pandas.core.series.Series

# %%
sample['שם']
# Out:
# 0      אליז
# 1    בת שבע
# 2      גליה
# 3      נעמי
# Name: שם, dtype: object

# %%
sample[sample["כיתה"]==12]
# Out:
#      שם  כיתה  ממוצע ציונים
# 0  אליז    12            42

# %%
sample["ממוצע ציונים"].max()
# Out:
# 99

# %%
df = pd.read_csv('cities.csv')

# %%
df
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['LatD'].mean()
# Out:
# 38.8203125

# %%
df['LatD'].min()
# Out:
# 26

# %%
df['LatD'].max()
# Out:
# 50

# %%
df['ratio'] = df["LatD"]/df["LatS"]

# %%
df
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State     ratio
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# 3           "Worcester"     MA  3.500000
# ...

# %%
df.rename(columns={'LonD': 'Population'}, inplace=True)

# %%
rslt_df = df[df['City'] == '"Youngstown"']
rslt_df
# Out:
# Empty DataFrame
# Columns: [LatD,  "LatM", LatS, NS, Population,  LonM"",  "LonS",  EW, City,  State, ratio]
# Index: []

# %%
df.sort_values(by='LatD', ascending=False)
# Out:
#      LatD   "LatM"  LatS    NS  Population   LonM""   "LonS"    EW  \
# 124    50       25    11   "N"         104       39        0   "W"
# 33     49       16    12   "N"         123        7       12   "W"
# 6      49       52    48   "N"          97        9        0   "W"
# 10     48        9     0   "N"         103       37       12   "W"
# 54     47       14    24   "N"         122       25       48   "W"
# ..    ...      ...   ...   ...         ...      ...      ...   ...
# 108    29       53    23   "N"          81       19       11   "W"
# 31     28       48    35   "N"          97        0       36   "W"
# 84     27       20    24   "N"          82       31       47   "W"
# 52     27       57     0   "N"          82       26       59   "W"
# 16     26       43    11   "N"          80        3        0   "W"
#
#                    City  State     ratio
# 124            "Regina"     SA  4.545455
# 33          "Vancouver"     BC  4.083333
# ...

# %%
df_citys = df['City']
sorted_df = df_citys.sort_values()

# %%
sorted_df
# Out:
# 127        "Ravenna"
# 126        "Reading"
# 125      "Red Bluff"
# 124         "Regina"
# 123           "Reno"
#            ...
# 3        "Worcester"
# 2           "Yakima"
# 1          "Yankton"
# 0       "Youngstown"
# 11              null
# Name: City, Length: 128, dtype: object

# %%
sorted_df.to_csv('sortedCSV')
